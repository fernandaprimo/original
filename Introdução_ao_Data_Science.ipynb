# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandaprimo/original/blob/main/Introdu%C3%A7%C3%A3o_ao_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**Analisando as notas em geral**

# %%
import pandas as pd

notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas["nota"].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
print ("Media",notas["nota"].mean())
print ("Mediana",notas.nota.median())
# Out:
# Media 3.501556983616962
# Mediana 3.5

# %%
notas.nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas.nota.plot(kind='hist')

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.nota)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ##**Olhando os filmes**

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["filmeId", "titulos", "generos"]
filmes.head()
# Out:
#    filmeId                             titulos  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %% [markdown]
# ##**Analisando algumas notas especificas por filme**

# %%
notas.query("filmeId==1").nota.mean()
# Out:
# 3.9209302325581397

# %%
medias_por_filme = notas.groupby("filmeId").mean().nota
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5,8))

sns.boxplot(y=medias_por_filme)

# %%
medias_por_filme.describe
# Out:
# <bound method NDFrame.describe of filmeId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64>

# %%
sns.distplot(medias_por_filme)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.hist(medias_por_filme)
plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %%
tmdb = pd.read_csv("tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.original_language.unique() #categorica nominal
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb.vote_average.unique()
# Out:
# array([ 7.2,  6.9,  6.3,  7.6,  6.1,  5.9,  7.4,  7.3,  5.7,  5.4,  7. ,
#         6.5,  6.4,  6.2,  7.1,  5.8,  6.6,  7.5,  5.5,  6.7,  6.8,  6. ,
#         5.1,  7.8,  5.6,  5.2,  8.2,  7.7,  5.3,  8. ,  4.8,  4.9,  7.9,
#         8.1,  4.7,  5. ,  4.2,  4.4,  4.1,  3.7,  3.6,  3. ,  3.9,  4.3,
#         4.5,  3.4,  4.6,  8.3,  3.5,  4. ,  2.3,  3.2,  0. ,  3.8,  2.9,
#         8.5,  1.9,  3.1,  3.3,  2.2,  0.5,  9.3,  8.4,  2.7, 10. ,  1. ,
#         2. ,  2.8,  9.5,  2.6,  2.4])

# %%
tmdb.original_language.value_counts()
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# nl       4
# fa       4
# th       3
# he       3
# ta       2
# cs       2
# ro       2
# id       2
# ar       2
# vi       1
# sl       1
# ps       1
# no       1
# ky       1
# hu       1
# pl       1
# af       1
# nb       1
# tr       1
# is       1
# xx       1
# te       1
# el       1
# Name: original_language, dtype: int64

# %%
contagem_de_lingua = tmdb.original_language.value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ["original_language", "total"]
contagem_de_lingua.head()
# Out:
#   original_language  total
# 0                en   4505
# 1                fr     70
# 2                es     32
# 3                zh     27
# 4                de     27

# %%
sns.barplot(x = "original_language", y = "total", data = contagem_de_lingua)

# %%
sns.catplot(x="original_language", kind="count", data=tmdb)

# %%
plt.pie(contagem_de_lingua["total"], labels = contagem_de_lingua["original_language"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5a31e66fa0>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'en'),
#   Text(1.0355355017029462, -0.3710339940124459, 'fr'),
#   Text(1.0579676486019882, -0.3011718023181785, 'es'),
#   Text(1.0687996606645356, -0.26012936274741094, 'zh'),
#   Text(1.0773191105706255, -0.22222406260195313, 'de'),
#   Text(1.0835167978583342, -0.18971386021801853, 'hi'),
#   Text(1.0875756432724297, -0.16486121484618815, 'ja'),
#   Text(1.0906010773146022, -0.14348968659882622, 'it'),
#   Text(1.092883487371409, -0.12492270822755745, 'cn'),
#   Text(1.0946390911069936, -0.10846778425161549, 'ru'),
#   Text(1.0960865535188649, -0.09270527058984593, 'ko'),
#   Text(1.0972054830031333, -0.07835896928789601, 'pt'),
#   Text(1.097965443340663, -0.06687215586282344, 'da'),
#   Text(1.0984565010300316, -0.05825217030171998, 'sv'),
#   Text(1.0987803851616647, -0.0517847968421653, 'nl'),
#   Text(1.0990363161210686, -0.04603450713357274, 'fa'),
# ...

# %%
total_por_lingua = tmdb["original_language"].value_counts()
total_geral = total_por_lingua.sum()
total_de_ingles = total_por_lingua.loc["en"]
total_do_resto = total_geral - total_de_ingles
print(total_de_ingles, total_do_resto)
# Out:
# 4505 298

# %%
dados = {
    'lingua' : ['ingles','outros'],
    'total' : [total_de_ingles, total_do_resto]

}

pd.DataFrame(dados)
# Out:
#    lingua  total
# 0  ingles   4505
# 1  outros    298

# %%
sns.barplot(data = dados, x = 'lingua', y = 'total')

# %%
plt.pie(dados["total"], labels = dados["lingua"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f5a31d044f0>,
# ...
#  [Text(-1.0791697536499925, 0.2130554923183512, 'ingles'),
#   Text(1.0791697511565306, -0.2130555049482467, 'outros')])

# %%
filmes_lingua_original_em_ingles = tmdb.query("original_language == 'en'")

# %%
filmes_sem_lingua_original_em_ingles = tmdb.query("original_language != 'en'")

# %%
total_por_lingua_de_outros_filmes = tmdb.query("original_language != 'en'").original_language.value_counts()

# %%
sns.catplot(x = "original_language", kind="count", 
            data = filmes_sem_lingua_original_em_ingles,
            aspect = 2, 
            palette="mako",
            order = total_por_lingua_de_outros_filmes.index)

# %% [markdown]
# # Revisando o papel da média, mediana, medidas de tendencia de tendência central, dispersão, desviso padrão, box plot e histograma

# %%
notas_do_toy_story = notas.query("filmeId==1")
notas_do_jumanji = notas.query("filmeId==2")
print(len(notas_do_toy_story), len(notas_do_jumanji))
# Out:
# 215 110

# %%
print("Nota média do Toy Story %.2f" % notas_do_toy_story.nota.mean())
print("Nota média do Jumanji %.2f" % notas_do_jumanji.nota.mean())
# Out:
# Nota média do Toy Story 3.92
# Nota média do Jumanji 3.43

# %%
print("Mediana do Toy Story %.2f" % notas_do_toy_story.nota.median())
print("Mediana do Jumanji %.2f" % notas_do_jumanji.nota.median())
# Out:
# Mediana do Toy Story 4.00
# Mediana do Jumanji 3.50

# %%
import numpy as np

np.array([2.5] * 10)
# Out:
# array([2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5, 2.5])

# %%
import numpy as np

np.array([2.5] * 10).mean()
# Out:
# 2.5

# %%
filme1 = np.append(np.array([2.5] * 10), np.array([3.5] * 10))
filme2 = np.append(np.array([5] * 10), np.array([1] * 10))

print(filme1.mean(), filme2.mean())
print(np.median(filme1), np.median(filme2))
# Out:
# 3.0 3.0
# 3.0 3.0

# %%
plt.hist(filme1)
plt.hist(filme2)
# Out:
# (array([10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0., 10.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot([filme1,filme2])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f5a37086c10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f5a36f640a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f5a348f41f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f5a370394c0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5a348e05e0>,
# ...
#  'means': []}

# %%
plt.boxplot([notas_do_toy_story.nota, notas_do_jumanji.nota])
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f5a31d7ef10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f5a34703bb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f5a31d7ebb0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f5a347a9e50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f5a31e97340>,
# ...
#  'means': []}

# %%
sns.boxplot(x = "filmeId", y = "nota", data = notas.query("filmeId in (1, 2)"))

# %%
sns.boxplot(x = "filmeId", y = "nota", data = notas.query("filmeId in (1, 2, 3, 4, 5)"))

# %%
print("Desvio padrão do Jumanji %.2f" % notas_do_jumanji.nota.std(), "Desvio padrão do Toy Story %.2f" % notas_do_toy_story.nota.std())
# Out:
# Desvio padrão do Jumanji 0.88 Desvio padrão do Toy Story 0.83

# %%
print(np.mean(filme1), np.mean(filme2))
print(np.std(filme1), np.std(filme2))
print(np.median(filme1), np.median(filme2))
# Out:
# 3.0 3.0
# 0.5 2.0
# 3.0 3.0
